# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('dados/resultado-00000-of-00001.csv', delimiter=';')
df
# Out:
#      UF  YEAR  MONTH  RAINFALL  DENGUE_CASES
# 0    SP  2015      1    4465.0         772.0
# 1    SP  2015      2    6595.0        3086.0
# 2    SP  2015      3    6210.6        8824.0
# 3    SP  2015      4    1862.0        9932.0
# 4    SP  2015      5    2756.6        8919.0
# ..   ..   ...    ...       ...           ...
# 415  ES  2019      8     662.6        3462.0
# 416  ES  2019      9     696.8        2525.0
# 417  ES  2019     10     738.6        1566.0
# 418  ES  2019     11    3629.0        1537.0
# 419  ES  2019     12    1719.0        1272.0
#
# [420 rows x 5 columns]

# %%
df_group_by = df.groupby(['UF', 'YEAR'])[['RAINFALL', 'DENGUE_CASES']].mean().round(2).reset_index()
df_group_by.head()
# Out:
#    UF  YEAR  RAINFALL  DENGUE_CASES
# 0  CE  2015    771.78       5014.25
# 1  CE  2016    533.70       5433.08
# 2  CE  2017    775.35       5519.67
# 3  CE  2018    797.95       1070.08
# 4  CE  2019    809.00       2559.25

# %%
df_CE = df_group_by.loc[lambda x: x['UF'] == 'CE']
df_ES = df_group_by.loc[lambda x: x['UF'] == 'ES']
df_MG = df_group_by.loc[lambda x: x['UF'] == 'MG']
df_PR = df_group_by.loc[lambda x: x['UF'] == 'PR']
df_RJ = df_group_by.loc[lambda x: x['UF'] == 'RJ']
df_RS = df_group_by.loc[lambda x: x['UF'] == 'RS']
df_SP = df_group_by.loc[lambda x: x['UF'] == 'SP']

# %%
ax = sns.pointplot(df_CE, x='YEAR', y='DENGUE_CASES', markers='o')
ax.set_title('Media de casos de dengue x Ano no estado do Ceara')
ax.set_xlabel('Ano')
ax.set_ylabel('Casos de dengue')
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: title={'center': 'Media de casos de dengue x Ano no estado do Ceara'}, xlabel='Ano', ylabel='Casos de dengue'>

# %%
ax = sns.pointplot(df_ES, x='YEAR', y='DENGUE_CASES', markers='o')
ax.set_title('Media de casos de dengue x Ano no estado do Espirito Santo')
ax.set_xlabel('Ano')
ax.set_ylabel('Casos de dengue')
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: title={'center': 'Media de casos de dengue x Ano no estado do Espirito Santo'}, xlabel='Ano', ylabel='Casos de dengue'>

# %%
ax = sns.pointplot(df_MG, x='YEAR', y='DENGUE_CASES', markers='o')
ax.set_title('Media de casos de dengue x Ano no estado de Minas Gerais')
ax.set_xlabel('Ano')
ax.set_ylabel('Casos de dengue')
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: title={'center': 'Media de casos de dengue x Ano no estado de Minas Gerais'}, xlabel='Ano', ylabel='Casos de dengue'>

# %%
ax = sns.pointplot(df_PR, x='YEAR', y='DENGUE_CASES', markers='o')
ax.set_title('Media de casos de dengue x Ano no estado do Parana')
ax.set_xlabel('Ano')
ax.set_ylabel('Casos de dengue')
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: title={'center': 'Media de casos de dengue x Ano no estado do Parana'}, xlabel='Ano', ylabel='Casos de dengue'>

# %%
ax = sns.pointplot(df_RJ, x='YEAR', y='DENGUE_CASES', markers='o')
ax.set_title('Media de casos de dengue x Ano no estado do Rio de Janeiro')
ax.set_xlabel('Ano')
ax.set_ylabel('Casos de dengue')
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: title={'center': 'Media de casos de dengue x Ano no estado do Rio de Janeiro'}, xlabel='Ano', ylabel='Casos de dengue'>

# %%
ax = sns.pointplot(df_RS, x='YEAR', y='DENGUE_CASES', markers='o')
ax.set_title('Media de casos de dengue x Ano no estado do Rio Grande do Sul')
ax.set_xlabel('Ano')
ax.set_ylabel('Casos de dengue')
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: title={'center': 'Media de casos de dengue x Ano no estado do Rio Grande do Sul'}, xlabel='Ano', ylabel='Casos de dengue'>

# %%
ax = sns.pointplot(df_SP, x='YEAR', y='DENGUE_CASES', markers='o')
ax.set_title('Media de casos de dengue x Ano no estado de Sao Paulo')
ax.set_xlabel('Ano')
ax.set_ylabel('Casos de dengue')
ax.figure.set_size_inches(12,6)
ax
# Out:
# <Axes: title={'center': 'Media de casos de dengue x Ano no estado de Sao Paulo'}, xlabel='Ano', ylabel='Casos de dengue'>
